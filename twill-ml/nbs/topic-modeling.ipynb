# %%
# Autoreload

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# Set Path to Project Root in jupyter notebook
# %cd ..
# Out:
# /Users/meghanabhange/Documents/repos/twill/twill-ml

# %%
# Imports 
from twill_ml.dataloader import TwitterDataLoader
from twill_ml.config import get_env, get_data_path
# Out:
#   Cell In [22], line 4
#     from twill_core
#                    ^
# SyntaxError: invalid syntax

# %%
dl = TwitterDataLoader()
df = dl.load()
df = dl.preprocess()
df
# Out:
#                                         _id  revision_id   author_id  \
# 0    {'$numberLong': '1566389127590862848'}          NaN  1254087536
# 1    {'$numberLong': '1565696253782106112'}          NaN  1254087536
# 2    {'$numberLong': '1564692158602518529'}          NaN  1254087536
# 3    {'$numberLong': '1564636585785806850'}          NaN  1254087536
# 4    {'$numberLong': '1564253259262562306'}          NaN  1254087536
# ..                                      ...          ...         ...
# 117  {'$numberLong': '1570464555540811778'}          NaN  1254087536
# 118  {'$numberLong': '1570266413809664001'}          NaN  1254087536
# 119  {'$numberLong': '1571091781869244417'}          NaN  1254087536
# 120  {'$numberLong': '1571084249998196736'}          NaN  1254087536
# 121  {'$numberLong': '1571068708961030144'}          NaN  1254087536
#
#                                        organic_metrics      conversation_id  \
# 0    {'reply_count': 0, 'retweet_count': 0, 'url_li...  1566389127590862848
# 1    {'reply_count': 0, 'retweet_count': 0, 'url_li...  1565696253782106112
# 2    {'reply_count': 0, 'retweet_count': 0, 'url_li...  1564639434028507136
# 3    {'reply_count': 0, 'retweet_count': 0, 'url_li...  1564636585785806848
# 4    {'reply_count': 0, 'retweet_count': 0, 'url_li...  1563820992627105792
# ..                                                 ...                  ...
# 117  {'reply_count': 0, 'retweet_count': 0, 'url_li...  1570464555540811776
# 118  {'reply_count': 0, 'retweet_count': 0, 'url_li...  1570178470910783488
# 119  {'reply_count': 0, 'retweet_count': 0, 'url_li...  1570782081499922432
# 120  {'reply_count': 0, 'retweet_count': 0, 'url_li...  1571068708961030144
# 121  {'reply_count': 1, 'retweet_count': 0, 'url_li...  1571068708961030144
#
#                                                   text  \
# 0    @JustJake Is there any way to point a deployme...
# 1    Ever wondered how rental/booking apps efficien...
# 2    @marcelotryle @anastasiatymo So inspiring, as ...
# 3    Setup a small SvelteKit + FastAPI app this wee...
# 4    Here it is! 😁\n\nFirst time I do a technical d...
# ..                                                 ...
# 117  Can't believe Adobe acquiring Figma 😭\n\nI lov...
# 118  @jamgregory @samwhoo After running overnight, ...
# 119           @SaryWrites Always acceptable in my book
# 120  @roman_the_right I still like Microsoft 10x mo...
# 121  It's so sad how companies are agreeing to gett...
#
#                                       created_at  in_reply_to_user_id  \
# 0    {'$date': {'$numberLong': '1662291244000'}}         6.075285e+08
# 1    {'$date': {'$numberLong': '1662126050000'}}                  NaN
# 2    {'$date': {'$numberLong': '1661886655000'}}         1.240764e+18
# 3    {'$date': {'$numberLong': '1661873406000'}}                  NaN
# 4    {'$date': {'$numberLong': '1661782014000'}}         1.254088e+09
# ..                                           ...                  ...
# 117  {'$date': {'$numberLong': '1663262902000'}}                  NaN
# 118  {'$date': {'$numberLong': '1663215661000'}}         6.026428e+07
# 119  {'$date': {'$numberLong': '1663412444000'}}         1.547577e+18
# 120  {'$date': {'$numberLong': '1663410649000'}}         1.372541e+18
# 121  {'$date': {'$numberLong': '1663406943000'}}                  NaN
#
#                                                  tweet
# 0    $MENTION$ Is there any way to point a deployme...
# 1    Ever wondered how rental/booking apps efficien...
# 2    $MENTION$ $MENTION$ So inspiring, as usual $ME...
# 3    Setup a small SvelteKit + FastAPI app this wee...
# 4    Here it is! 😁 First time I do a technical deep...
# ..                                                 ...
# 117  Can't believe Adobe acquiring Figma 😭 I love i...
# 118  $MENTION$ $MENTION$ After running overnight, r...
# 119             $MENTION$ Always acceptable in my book
# 120  $MENTION$ I still like Microsoft $NUMBER$x mor...
# 121  It's so sad how companies are agreeing to gett...
#
# [122 rows x 9 columns]

# %% [markdown]
# #
